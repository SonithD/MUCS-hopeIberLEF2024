# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow
# !pip install tensorflow-text
# !pip install spacy
# !pip install contractions
# !pip install emoji
# !pip install emot
# !pip install demoji
# !pip install nlpaug
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
# ...

# %%
# !pip install transformers==4.30.2
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 52.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.7 MB/s eta 0:00:00
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd

import spacy
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
import contractions
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re
from nltk.tokenize import TweetTokenizer
import regex
import nltk
from nltk.stem import SnowballStemmer
import demoji
import emoji
from sklearn.metrics import f1_score
import os
# os.environ["MODEL_DIR"] = '/content/drive/MyDrive/homo/Model'
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
from nlpaug.util import Action
demoji.download_codes()
lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report,accuracy_score
from sklearn.svm import LinearSVC
# Out:
# <ipython-input-4-c9e993dd6981>:24: FutureWarning: The demoji.download_codes attribute is deprecated and will be removed from demoji in a future version. It is an unused attribute as emoji codes are now distributed directly with the demoji package.
#   demoji.download_codes()

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('whitespace')
nltk.download('wordnet')
nltk.download('omw-1.4')
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading whitespace: Package 'whitespace' not found
# [nltk_data]     in index
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df_train = pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task2_Span/train.csv')
df_val=pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task2_Span/val.csv')
df_test=pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task2_Span/Task2_ES_test_no_label.csv')

# %%
df_train
# Out:
#                                                    text    binary  \
# 0     Mientras me persigno y le rezo a la Virgen del...  Not Hope
# 1     No.. Yo ya no estoy para esperar.. Ni para rog...  Not Hope
# 2     Creo que estamos ante el mejor episodio de est...      Hope
# 3     Bueno ojalá q cuando llegue este fin de semana...      Hope
# 4     #USER# #USER# Marcos de boludo no tiene un pel...  Not Hope
# ...                                                 ...       ...
# 6898  #USER# buenos días bella. De nuevo la saludo c...      Hope
# 6899  🔴 GASTRO | I Jornadas de los Gazpachos en Bar ...  Not Hope
# 6900  La nuera le contó al Dr Petro todas las irregu...  Not Hope
# 6901  No sé por qué no me siento listo para una rela...  Not Hope
# 6902  #USER# #USER# Interesante que habla de un prem...  Not Hope
#
#             multiclass    id
# 0             Not Hope  5533
# 1             Not Hope   549
# 2     Generalized Hope  4350
# 3       Realistic Hope  3593
# ...

# %%
df_train['multiclass'].value_counts()
# Out:
# multiclass
# Not Hope            4701
# Generalized Hope    1151
# Unrealistic Hope     546
# Realistic Hope       505
# Name: count, dtype: int64

# %%
df_val['multiclass'].value_counts()
# Out:
# multiclass
# Not Hope            799
# Generalized Hope    186
# Unrealistic Hope     91
# Realistic Hope       74
# Name: count, dtype: int64

# %%
df_test.head()
# Out:
#                                                 text    id
# 0  Voy a subir Anhelo, es la historia de Judith y...  3020
# 1  #USER# Le dije q iba a tener q ingerir varios ...  7123
# 2  RT #USER# Esperando las pruebas femeninas en l...  5378
# 3  #USER# Esperanza Aguirre no es que hable inglé...  8396
# 4  RT #USER# Quiero deseo anhelo manifiesto estar...  7885

# %%
len(df_test)
# Out:
# 1152

# %%
df_train['tokenized_sents'] = df_train.apply(lambda row: nltk.sent_tokenize(row['text']), axis=1)

# %%
df_train['tok_sent']= df_train['tokenized_sents']
df_train
# Out:
#                                                    text    binary  \
# 0     Mientras me persigno y le rezo a la Virgen del...  Not Hope
# 1     No.. Yo ya no estoy para esperar.. Ni para rog...  Not Hope
# 2     Creo que estamos ante el mejor episodio de est...      Hope
# 3     Bueno ojalá q cuando llegue este fin de semana...      Hope
# 4     #USER# #USER# Marcos de boludo no tiene un pel...  Not Hope
# ...                                                 ...       ...
# 6898  #USER# buenos días bella. De nuevo la saludo c...      Hope
# 6899  🔴 GASTRO | I Jornadas de los Gazpachos en Bar ...  Not Hope
# 6900  La nuera le contó al Dr Petro todas las irregu...  Not Hope
# 6901  No sé por qué no me siento listo para una rela...  Not Hope
# 6902  #USER# #USER# Interesante que habla de un prem...  Not Hope
#
#             multiclass    id  \
# 0             Not Hope  5533
# 1             Not Hope   549
# 2     Generalized Hope  4350
# 3       Realistic Hope  3593
# ...

# %%
df_train['tok_sent']
# Out:
# 0       [Mientras me persigno y le rezo a la Virgen de...
# 1       [No.. Yo ya no estoy para esperar.. Ni para ro...
# 2       [Creo que estamos ante el mejor episodio de es...
# 3       [Bueno ojalá q cuando llegue este fin de seman...
# 4       [#USER# #USER# Marcos de boludo no tiene un pe...
#                               ...
# 6898    [#USER# buenos días bella., De nuevo la saludo...
# 6899    [🔴 GASTRO | I Jornadas de los Gazpachos en Bar...
# 6900    [La nuera le contó al Dr Petro todas las irreg...
# 6901    [No sé por qué no me siento listo para una rel...
# 6902    [#USER# #USER# Interesante que habla de un pre...
# Name: tok_sent, Length: 6903, dtype: object

# %%
# !pip install nlpaug

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc
from nlpaug.util import Action
import os

# %%
os.environ["MODEL_DIR"]= '/content/drive/MyDrive/HOPE2024/Task2_Seperate_Code/Model'

# %%
aug1, aug2, aug3 = naw.TfIdfAug(model_path=os.environ.get("MODEL_DIR"), action="insert"), naw.SynonymAug(aug_src='wordnet'), naw.TfIdfAug(model_path=os.environ.get("MODEL_DIR"),action="substitute")

# %%
df_train['multiclass'].value_counts()
# Out:
# multiclass
# Not Hope            4701
# Generalized Hope    1151
# Unrealistic Hope     546
# Realistic Hope       505
# Name: count, dtype: int64

# %%
df_trainGH=df_train[df_train["multiclass"]=='Generalized Hope']
df_trainGH
# Out:
#                                                    text binary  \
# 2     Creo que estamos ante el mejor episodio de est...   Hope
# 5     #USER# Bella Cora también te deseo una feliz y...   Hope
# 11    A ti te rezo samuel, gran personaje de la cibe...   Hope
# 18    #USER# JAJAJAJAJAJAJA está esperando el mejor ...   Hope
# 21    bno, buenas noches mutis, les deseo una noche ...   Hope
# ...                                                 ...    ...
# 6885  Esperando la presentación de #BRIAN 🧎🏻‍♀️  #ボイ...   Hope
# 6887  #USER# Del creo al hecho... yo espero que todo...   Hope
# 6888  #USER# Ahh 🤤 a mí me toca mañana, ansío tanto ...   Hope
# 6897  #USER# #USER# #USER# #USER# Ojalá no la vaya a...   Hope
# 6898  #USER# buenos días bella. De nuevo la saludo c...   Hope
#
#             multiclass    id  \
# 2     Generalized Hope  4350
# 5     Generalized Hope  7598
# 11    Generalized Hope  1395
# 18    Generalized Hope  3629
# 21    Generalized Hope  1540
# ...

# %%
df_trainUH=df_train[df_train["multiclass"]=='Unrealistic Hope']
df_trainUH
# Out:
#                                                    text binary  \
# 17    No puedo esperar a estar en la playa con mis a...   Hope
# 33    RT #USER# Mi único deseo es que se vaya este c...   Hope
# 35    Ojalá que este domingo Zaldivia se transforme ...   Hope
# 42    Ojalá volver a estar en ese momento porque des...   Hope
# 67    Buenas noches, deseando que el vejete saque es...   Hope
# ...                                                 ...    ...
# 6819  No se que haría sin mi mamá cuando me da un at...   Hope
# 6853  #USER# Como desearía tener ese ligue para  hab...   Hope
# 6855  #USER# #USER# Ojalá se metieran en casa de sus...   Hope
# 6857  RT #USER# #PecadoOriginal1Mar Deseando ver al ...   Hope
# 6883  #USER# El sueño de cualquier terrorista es q n...   Hope
#
#             multiclass    id  \
# 17    Unrealistic Hope  6101
# 33    Unrealistic Hope  2811
# 35    Unrealistic Hope    80
# 42    Unrealistic Hope  9089
# 67    Unrealistic Hope  3264
# ...

# %%
df_trainRH=df_train[df_train["multiclass"]=='Realistic Hope']
df_trainRH
# Out:
#                                                    text binary  \
# 2     Creo que estamos ante el mejor episodio de est...   Hope
# 5     #USER# Bella Cora también te deseo una feliz y...   Hope
# 11    A ti te rezo samuel, gran personaje de la cibe...   Hope
# 18    #USER# JAJAJAJAJAJAJA está esperando el mejor ...   Hope
# 21    bno, buenas noches mutis, les deseo una noche ...   Hope
# ...                                                 ...    ...
# 6885  Esperando la presentación de #BRIAN 🧎🏻‍♀️  #ボイ...   Hope
# 6887  #USER# Del creo al hecho... yo espero que todo...   Hope
# 6888  #USER# Ahh 🤤 a mí me toca mañana, ansío tanto ...   Hope
# 6897  #USER# #USER# #USER# #USER# Ojalá no la vaya a...   Hope
# 6898  #USER# buenos días bella. De nuevo la saludo c...   Hope
#
#             multiclass    id  \
# 2     Generalized Hope  4350
# 5     Generalized Hope  7598
# 11    Generalized Hope  1395
# 18    Generalized Hope  3629
# 21    Generalized Hope  1540
# ...

# %%
augmented_texts1 = []
augmented_texts2 = []
augmented_texts3 = []
labels = []
for index, row in df_trainGH.iterrows():
    text = row['tok_sent']
    #print("Before : ", text)
    label = row['multiclass']
    label: df_trainGH['multiclass']
    text1 = aug1.augment(text)
    augmented_texts1.append(text1)
    text2 = aug2.augment(text)
    augmented_texts2.append(text2)
    text3 = aug3.augment(text)
    augmented_texts3.append(text3)
    #print("After :", text)
    labels.append(label)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
augmented_data1 = pd.DataFrame({
    'text': augmented_texts1,
    'labels': labels
})
augmented_data2 = pd.DataFrame({
    'text': augmented_texts2,
    'labels': labels
})
augmented_data3 = pd.DataFrame({
    'text': augmented_texts3,
    'labels': labels
})

# %%
augmented_texts4 = []
augmented_texts5 = []
augmented_texts6 = []
labels = []
for index, row in df_trainUH.iterrows():
    text = row['tok_sent']
    #print("Before : ", text)
    label = row['multiclass']
    label: df_trainUH['multiclass']
    text1 = aug1.augment(text)
    augmented_texts4.append(text1)
    text2 = aug2.augment(text)
    augmented_texts5.append(text2)
    text3 = aug3.augment(text)
    augmented_texts6.append(text3)
    #print("After :", text)
    labels.append(label)

# %%
augmented_data4 = pd.DataFrame({
    'text': augmented_texts4,
    'labels': labels
})
augmented_data5 = pd.DataFrame({
    'text': augmented_texts5,
    'labels': labels
})
augmented_data6 = pd.DataFrame({
    'text': augmented_texts6,
    'labels': labels
})

# %%
augmented_texts7 = []
augmented_texts8 = []
augmented_texts9 = []
labels = []
for index, row in df_trainRH.iterrows():
    text = row['tok_sent']
    #print("Before : ", text)
    label = row['multiclass']
    label: df_trainRH['multiclass']
    text1 = aug1.augment(text)
    augmented_texts7.append(text1)
    text2 = aug2.augment(text)
    augmented_texts8.append(text2)
    text3 = aug3.augment(text)
    augmented_texts9.append(text3)
    #print("After :", text)
    labels.append(label)

# %%
augmented_data7 = pd.DataFrame({
    'text': augmented_texts7,
    'labels': labels
})
augmented_data8 = pd.DataFrame({
    'text': augmented_texts8,
    'labels': labels
})
augmented_data9 = pd.DataFrame({
    'text': augmented_texts9,
    'labels': labels
})

# %%
augmented_data10 = pd.DataFrame({
    'text': augmented_texts4,
    'labels': labels
})
augmented_data11 = pd.DataFrame({
    'text': augmented_texts5,
    'labels': labels
})
augmented_data12 = pd.DataFrame({
    'text': augmented_texts6,
    'labels': labels
})

# %%
augmented_data13 = pd.DataFrame({
    'text': augmented_texts7,
    'labels': labels
})
augmented_data14 = pd.DataFrame({
    'text': augmented_texts8,
    'labels': labels
})
augmented_data15 = pd.DataFrame({
    'text': augmented_texts9,
    'labels': labels
})

# %%
aug_data=pd.concat([augmented_data1, augmented_data2, augmented_data3,augmented_data4,augmented_data5,augmented_data6,augmented_data7,augmented_data8,augmented_data9,augmented_data10,augmented_data11, augmented_data12,augmented_data13, augmented_data14,augmented_data15])

# %%
aug_data['labels'].value_counts()
# Out:
# labels
# Generalized Hope    3453
# Unrealistic Hope    3276
# Realistic Hope      3030
# Name: count, dtype: int64

# %%
aug_data=aug_data.rename(columns={'labels':'multiclass'})

# %%
df_train
# Out:
#                                                    text    binary  \
# 0     Mientras me persigno y le rezo a la Virgen del...  Not Hope
# 1     No.. Yo ya no estoy para esperar.. Ni para rog...  Not Hope
# 2     Creo que estamos ante el mejor episodio de est...      Hope
# 3     Bueno ojalá q cuando llegue este fin de semana...      Hope
# 4     #USER# #USER# Marcos de boludo no tiene un pel...  Not Hope
# ...                                                 ...       ...
# 6898  #USER# buenos días bella. De nuevo la saludo c...      Hope
# 6899  🔴 GASTRO | I Jornadas de los Gazpachos en Bar ...  Not Hope
# 6900  La nuera le contó al Dr Petro todas las irregu...  Not Hope
# 6901  No sé por qué no me siento listo para una rela...  Not Hope
# 6902  #USER# #USER# Interesante que habla de un prem...  Not Hope
#
#             multiclass    id  \
# 0             Not Hope  5533
# 1             Not Hope   549
# 2     Generalized Hope  4350
# 3       Realistic Hope  3593
# ...

# %%
df_trainC=pd.DataFrame()

# %%
df_trainC['text']= df_train['text']
df_trainC['multiclass'] =df_train['multiclass']

# %%
joint_data = pd.concat([aug_data, df_trainC], ignore_index=True)
joint_data
# Out:
#                                                     text        multiclass
# 0      [Creo que estamos ante hello el mejor mentorin...  Generalized Hope
# 1      [# USER # Bella April Cora recruitment también...  Generalized Hope
# 2      [A main ti te rezo samuel, gran cars personaje...  Generalized Hope
# 3      [# china USER # assistant JAJAJAJAJAJAJA está ...  Generalized Hope
# 4      [bno, buenas noches mutis, les awarded deseo u...  Generalized Hope
# ...                                                  ...               ...
# 16657  #USER# buenos días bella. De nuevo la saludo c...  Generalized Hope
# 16658  🔴 GASTRO | I Jornadas de los Gazpachos en Bar ...          Not Hope
# 16659  La nuera le contó al Dr Petro todas las irregu...          Not Hope
# 16660  No sé por qué no me siento listo para una rela...          Not Hope
# 16661  #USER# #USER# Interesante que habla de un prem...          Not Hope
#
# [16662 rows x 2 columns]

# %%
joint_data['multiclass'].value_counts()
# Out:
# multiclass
# Not Hope            4701
# Generalized Hope    4604
# Unrealistic Hope    3822
# Realistic Hope      3535
# Name: count, dtype: int64

# %%
# !pip install num2words
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 1.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=7392b3dabd0e3d7dc9fd3156de9869b27ec2a81877d4a18e8b8a9f187eff19b1
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# ...

# %%
#eemot_object = emot.core.emot()
ps =PorterStemmer()
lemmatiser = WordNetLemmatizer()
english_stopwords = stopwords.words('english')
exclude = set(string.punctuation)
def preprocess(text):
  text = contractions.fix(text.lower(), slang=True)
  text =re.sub("@ ?[A-Za-z0-9_]+", " ", text)
  text = text.replace('$', ' dollar ')
  text=re.sub(r'$', '', text)
  text= re.sub(r'’','', text)
  text=re.sub(r'¿','',text)
  text=re.sub('<.*?>','',text)
  text=re.sub(r'http\S+', '', text)
  text = ''.join(ch for ch in text if ch not in exclude)
  tokens = word_tokenize(text)
  #print("Tokens:", tokens)
  text = [t for t in tokens if t not in english_stopwords]
  text = " ".join(text)
  return text

# %%
import inflect
p = inflect.engine()

# %%
def number_to_words(text):
    return ' '.join(p.number_to_words(token) if token.isdigit() else token for token in text.split())

# %%
from nltk.corpus import stopwords, wordnet

# %%
import emoji
#import demoji
#demoji.download_codes()
def emo(text):
  temp=emoji.demojize(text,delimiters=(" "," "))
  temp=temp.replace("_","  ")
  return temp

# %%
joint_data['clean_text']=joint_data["text"].apply(lambda x:emo(x))
joint_data["clean_text"]=joint_data['clean_text'].apply(lambda X: number_to_words(X))
joint_data["clean_text"]=joint_data['clean_text'].apply(lambda X: preprocess(X))

# %%
df_val['clean_text']=df_val["text"].apply(lambda x:emo(x))
df_val["clean_text"]=df_val['clean_text'].apply(lambda X: number_to_words(X))
df_val["clean_text"]=df_val['clean_text'].apply(lambda X: preprocess(X))

# %%
df_test['clean_text']=df_test["text"].apply(lambda x:emo(x))
df_test["clean_text"]=df_test['clean_text'].apply(lambda X: number_to_words(X))
df_test["clean_text"]=df_test['clean_text'].apply(lambda X: preprocess(X))

# %%
df_test.head()

# %%
# Move last Column to First Column
new_cols = ["clean_text","multiclass"]
joint_data=joint_data[new_cols]
joint_data
# Out:
#                                               clean_text        multiclass
# 0      creo que estamos ante hello el mejor mentoring...  Generalized Hope
# 1      user bella april cora recruitment también colo...  Generalized Hope
# 2      main ti te rezo samuel gran cars personaje de ...  Generalized Hope
# 3      china user assistant jajajajajajaja está esper...  Generalized Hope
# 4      bno buenas noches mutis les awarded deseo una ...  Generalized Hope
# ...                                                  ...               ...
# 16657  user buenos días bella de nuevo la saludo con ...  Generalized Hope
# 16658  red circle gastro jornadas de los gazpachos en...          Not Hope
# 16659  la nuera le contó al dr petro todas las irregu...          Not Hope
# 16660  sé por qué siento listo para una relación al m...          Not Hope
# 16661  user user interesante que habla de un premio i...          Not Hope
#
# [16662 rows x 2 columns]

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
joint_data['multiclass']= label_encoder.fit_transform(joint_data['multiclass'])

joint_data['multiclass'].unique()
# Out:
# <ipython-input-71-0e4a0ccd51e5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joint_data['multiclass']= label_encoder.fit_transform(joint_data['multiclass'])
# array([0, 3, 2, 1])

# %%
joint_data

# %%
model = ClassificationModel('bert', 'mrm8488/distill-bert-base-spanish-wwm-cased-finetuned-spa-squad2-es', num_labels=4, args={'reprocess_input_data': True, 'overwrite_output_dir': True}, use_cuda=False)
#juanmvs/homophobia-mexican-spanish
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at mrm8488/distill-bert-base-spanish-wwm-cased-finetuned-spa-squad2-es and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
model.train_model(joint_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:610: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...
# Running Epoch 1 of 1:   0%|          | 0/2083 [00:00<?, ?it/s]
# (2083, 0.5990174611139751)

# %%
list_val_text1 = []
for text in df_val['clean_text']:
  list_val_text1.append(text)

# %%
val_pred, raw_val_outputs = model.predict(list_val_text1)
# Out:
# ...
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
predctval=label_encoder.inverse_transform(val_pred)

# %%
from sklearn.metrics import classification_report
print(classification_report(df_val['multiclass'], predctval))

# %%
list_test_text = []
for text in df_test['clean_text']:
  list_test_text.append(text)

# %%
test_pred, raw_test_outputs = model.predict(list_test_text)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
predct_Test=label_encoder.inverse_transform(test_pred)

# %%
predct_Test

# %%
len(predct_Test)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_testk = pd.DataFrame(data=predct_Test, columns=['Prediction'])
submission_t1span= pd.DataFrame()
submission_t1span['id'] = df_test['id']
submission_t1span['category'] = pred_testk
submission_t1span.to_csv('/content/drive/MyDrive/HOPE2024/Task2_Seperate_Code/Task2_Span_Code_AugmentDistilSpanBert.csv', index=None)
