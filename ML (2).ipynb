# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# !pip install spacy
# !pip install contractions
# !pip install emoji
# !pip install emot
# !pip install demoji
# !pip install nlpaug
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.9 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 12.4 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# Collecting emoji
#   Downloading emoji-2.11.0-py2.py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.11.0
# Collecting emot
#   Downloading emot-3.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: emot
# Successfully installed emot-3.1
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0
# Collecting nlpaug
#   Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.25.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (2.0.3)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (2.31.0)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (3.13.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.66.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.11

# %%
import pandas as pd
import tensorflow as tf
# import tensorflow_hub as hub
# import tensorflow_text as text
import pandas as pd
import spacy
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
import contractions
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re
from nltk.tokenize import TweetTokenizer
import emoji
import regex
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import demoji
import emoji
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('whitespace')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading whitespace: Package 'whitespace' not found
# [nltk_data]     in index
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
df_train = pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task1/training_t1_sp.csv')
df_val = pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task1/Task 1 - Validation set .csv')
df_test=pd.read_csv('/content/drive/MyDrive/HOPE2024/Dataset_Task1/Task 2 - Test set No label.csv')

# %%
df_train.head()
# Out:
#                     id                                               text  \
# 0  1409573191098511365  Si quieres saber lo diverso e inclusivo que es...
# 1  1413030472020631553  Y ya esta ya me he liberado.Es que las injusti...
# 2  1409489246608560128  me molesta mucho el discurso ese en favor del ...
# 3  1412169304372568070   Yo te lo explico.No se pueden cortar las vías...
# 4  1410109561814622210  8. No somos opositores al movimiento #LGTBI+, ...
#
#   category
# 0      nhs
# 1       hs
# 2      nhs
# 3       hs
# 4      nhs

# %%
df_train['category'].value_counts()
# Out:
# category
# nhs    700
# hs     700
# Name: count, dtype: int64

# %%
df_val['category'].value_counts()
# Out:
# category
# hs     100
# nhs    100
# Name: count, dtype: int64

# %% [markdown]
#  # Preprocessing

# %%
# !pip install num2words
# Out:
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (0.5.13)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words) (0.6.2)

# %%
import re
import string
import emoji
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import contractions

def preprocess(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Convert emojis to textual representation
    text = emoji.demojize(text, delimiters=(" ", " "))
    text = text.replace("_", "  ")

    # Remove special characters and punctuation
    exclude = set(string.punctuation + '🏳️‍⚧️🔍¿')
    text = ''.join(ch for ch in text if ch not in exclude)

    # Fix contractions
    text = contractions.fix(text, slang=True)

    # Remove usernames
    text = re.sub('@[a-zA-Z0-9_]*', '', text)

    # Replace '$' with 'dollar'
    text = text.replace('$', ' dollar ')

    # Convert text to lowercase
    text = text.lower()

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    english_stopwords = stopwords.words('spanish')
    text = [t for t in tokens if t not in english_stopwords]
    text = " ".join(text)

    return text

# %%
import inflect
p = inflect.engine()

# %%
def number_to_words(text):
    return ' '.join(p.number_to_words(token) if token.isdigit() else token for token in text.split())

# %%
from nltk.corpus import stopwords, wordnet

# %%
import emoji
#import demoji
#demoji.download_codes()
def emo(text):
  temp=emoji.demojize(text,delimiters=(" "," "))
  temp=temp.replace("_","  ")
  return temp

# %%
df_train['clean_text'] = df_train['text'].apply(lambda x:emo(x))
df_train["clean_text"]=df_train['clean_text'].apply(lambda X: number_to_words(X))
df_train["clean_text"]=df_train['clean_text'].apply(lambda X: preprocess(X))

# %%
df_val['clean_text'] = df_val['text'].apply(lambda x:emo(x))
df_val["clean_text"]=df_val['clean_text'].apply(lambda X: number_to_words(X))
df_val["clean_text"]=df_val['clean_text'].apply(lambda X: preprocess(X))

# %%
df_test['clean_text'] = df_test['text'].apply(lambda x:emo(x))
df_test["clean_text"]=df_test['clean_text'].apply(lambda X: number_to_words(X))
df_test["clean_text"]=df_test['clean_text'].apply(lambda X: preprocess(X))

# %%
df_test
# Out:
#                       id                                               text  \
# 0    1596901421516931072  iiiiii como amo a mis amigas soy totalmente ho...
# 1    1592726714735468544  ¿Qué necesidad tiene la gente de decirme que e...
# 2    1294982700865146880  si soy una inmigrante que legalmente puede vot...
# 3    1471000234348056576  Mis amigas :no soy lesbiana . Mis amigas borra...
# 4    1316785660016156672  🇦🇷🏳️‍⚧️La provincia de Buenos Aires  anunció e...
# ..                   ...                                                ...
# 395  1483471654894321664  Lo lamento mucho, cuanta rabia aquí estamos pa...
# 396  1644989803421638656  Oigan ahorita que lo pienso,cuando estaba más ...
# 397  1365045199391625216  🔍#Entrevista de  a , psicóloga, docente e inve...
# 398  1315616859572629504  Y seguimos con un racismo institucional muy gr...
# 399  1631658383211220992  'Puede ser una trampa'. El objetivo de esta in...
#
#                                             clean_text
# 0     iiiiii amo amigas totalmente homosexual gorditos
# 1    necesidad gente decirme gorda face with rollin...
# 2    si inmigrante legalmente puede votar robo trab...
# 3     amigas lesbiana amigas borrachas besito treeesss
# 4    argentina transgender flag provincia buenos ai...
# ..                                                 ...
# 395  lamento cuanta rabia aquí optar resistencia tr...
# 396  oigan ahorita piensocuando gorda feliz ahora j...
# 397  magnifying glass tilted left entrevista psicól...
# 398  seguimos racismo institucional grave hace thre...
# 399  puede ser trampa objetivo iniciativa canadá au...
#
# [400 rows x 3 columns]

# %%
df_train = df_train.drop('text', axis='columns')
df_train
# Out:
#                        id category  \
# 0     1409573191098511365      nhs
# 1     1413030472020631553       hs
# 2     1409489246608560128      nhs
# 3     1412169304372568070       hs
# 4     1410109561814622210      nhs
# ...                   ...      ...
# 1395  1409474601831309317       hs
# 1396  1414347745427697667      nhs
# 1397  1409797952860721153       hs
# 1398  1411689668433829890      nhs
# 1399  1409493212406988802       hs
#
#                                              clean_text
# 0     si quieres saber diverso inclusivo ecuador vis...
# 1     liberadoes injusticias pueden apoyo mucha fuer...
# 2     molesta discurso favor orgullolgtbi enfatiza c...
# 3     explicono pueden cortar vías públicas autoriza...
# 4     8 opositores movimiento lgtbi contrario consid...
# ...                                                 ...
# 1395  hoy día orgullo mil razones festejarlo¡feliz d...
# 1396  señores muchas veces gente lgtb sale armario a...
# 1397  fuerte abrazo andalucía felicitaciones magnífi...
# 1398  siguen perdiendo oportunidades materia lgtbi f...
# 1399  día orgullolgtbi reporta two thousand and twen...
#
# [1400 rows x 3 columns]

# %%
# Move last Column to First Column
new_cols = ["clean_text","category"]
df_train=df_train[new_cols]
df_train
# Or
# df=df.reindex(columns=new_cols)
# print(df)
# Out:
#                                              clean_text category
# 0     si quieres saber diverso inclusivo ecuador vis...      nhs
# 1     liberadoes injusticias pueden apoyo mucha fuer...       hs
# 2     molesta discurso favor orgullolgtbi enfatiza c...      nhs
# 3     explicono pueden cortar vías públicas autoriza...       hs
# 4     8 opositores movimiento lgtbi contrario consid...      nhs
# ...                                                 ...      ...
# 1395  hoy día orgullo mil razones festejarlo¡feliz d...       hs
# 1396  señores muchas veces gente lgtb sale armario a...      nhs
# 1397  fuerte abrazo andalucía felicitaciones magnífi...       hs
# 1398  siguen perdiendo oportunidades materia lgtbi f...      nhs
# 1399  día orgullolgtbi reporta two thousand and twen...       hs
#
# [1400 rows x 2 columns]

# %% [markdown]
# Transliteration
# code-mixed text - all to romanized form

# %% [markdown]
# **Feature Extraction**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Tfidf_vec = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), max_df=1.0, min_df=1)
count_train = Tfidf_vec.fit(df_train['clean_text'])
train_features1 = Tfidf_vec.transform(df_train['clean_text'])
val_features1 = Tfidf_vec.transform(df_val['clean_text'])

# %%
test_features1 = Tfidf_vec.transform(df_test['clean_text'])

# %% [markdown]
#  # Model Building with SVM

# %% [markdown]
#  SVM- Linear SVC

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.svm import LinearSVC
clf_LSVC =LinearSVC(C=1.0, class_weight="balanced", max_iter=10000, random_state=123)
clf_LSVC.fit(train_features1, df_train['category'])
val_pred=clf_LSVC.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred))
# Out:
# Dev Accuracy: 75.5
#
#                precision    recall  f1-score   support
#
#           hs       0.77      0.73      0.75       100
#          nhs       0.74      0.78      0.76       100
#
#     accuracy                           0.76       200
#    macro avg       0.76      0.76      0.75       200
# weighted avg       0.76      0.76      0.75       200

# %%
test_predLSVC=clf_LSVC.predict(test_features1)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test1 = pd.DataFrame(data=test_predLSVC, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test1
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_LSVC_75.csv', index = None)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Initialize the CatBoost classifier
model = CatBoostClassifier(iterations=1000,  # Number of trees (default is 1000)
                           learning_rate=0.1,  # Learning rate (default is 0.03)
                           depth=6,  # Depth of the trees (default is 6)
                           loss_function='MultiClass',  # Loss function (default is 'Logloss')
                           verbose=100  # Controls the level of verbosity (default is 100)
                           )

# Train the model
model.fit(train_features1, df_train['category'], eval_set=(val_features1, df_val['category']), early_stopping_rounds=50, verbose=100)

# Predictions on the test set
y_pred = model.predict(val_features1)

# Calculate accuracy
accuracy = accuracy_score(df_val['category'], y_pred)
print("Accuracy:", accuracy)
# Out:
# 0:	learn: 0.6725482	test: 0.6887085	best: 0.6887085 (0)	total: 507ms	remaining: 8m 26s
# 100:	learn: 0.4216180	test: 0.5727029	best: 0.5727029 (100)	total: 33.7s	remaining: 4m 59s
# 200:	learn: 0.3439177	test: 0.5591002	best: 0.5584481 (198)	total: 1m 9s	remaining: 4m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.553397406
# bestIteration = 220
#
# Shrink model to first 221 iterations.
# Accuracy: 0.71

# %%
print("\n", classification_report(df_val['category'], y_pred))
# Out:
#                precision    recall  f1-score   support
#
#           hs       0.73      0.66      0.69       100
#          nhs       0.69      0.76      0.72       100
#
#     accuracy                           0.71       200
#    macro avg       0.71      0.71      0.71       200
# weighted avg       0.71      0.71      0.71       200

# %%
y_pred_test = model.predict(test_features1)

# %%
y_pred_test

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test2 = pd.DataFrame(data=y_pred_test, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test2
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_catBoost_71.csv', index = None)

# %%
len(submission_t1)
# Out:
# 400

# %%
from sklearn.linear_model import LogisticRegression
LRmodel = LogisticRegression(max_iter=1000)
LRmodel.fit(train_features1, df_train['category'])
val_pred=LRmodel.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred))
# Out:
# Dev Accuracy: 74.0
#
#                precision    recall  f1-score   support
#
#           hs       0.82      0.62      0.70       100
#          nhs       0.69      0.86      0.77       100
#
#     accuracy                           0.74       200
#    macro avg       0.75      0.74      0.74       200
# weighted avg       0.75      0.74      0.74       200

# %%
test_predLR=LRmodel.predict(test_features1)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test3 = pd.DataFrame(data=test_predLR, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test3
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_LR_74.csv', index = None)

# %%
from sklearn.ensemble import RandomForestClassifier
RFCModel = RandomForestClassifier(n_estimators=100, random_state=42)
RFCModel.fit(train_features1, df_train['category'])
val_pred1=RFCModel.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred1)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred1))
# Out:
# Dev Accuracy: 69.0
#
#                precision    recall  f1-score   support
#
#           hs       0.82      0.49      0.61       100
#          nhs       0.64      0.89      0.74       100
#
#     accuracy                           0.69       200
#    macro avg       0.73      0.69      0.68       200
# weighted avg       0.73      0.69      0.68       200

# %%
test_predRFC=RFCModel.predict(test_features1)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test4 = pd.DataFrame(data=test_predRFC, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test4
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_RFC_68.csv', index = None)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df_train['category']= label_encoder.fit_transform(df_train['category'])

df_train['category'].unique()
# Out:
# <ipython-input-116-721457236692>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['category']= label_encoder.fit_transform(df_train['category'])
# array([1, 0])

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df_val['category']= label_encoder.fit_transform(df_val['category'])

df_val['category'].unique()
# Out:
# array([0, 1])

# %%
import xgboost as xgb
xgbmodel = xgb.XGBClassifier(objective='binary:logistic', random_state=42)
xgbmodel.fit(train_features1, df_train['category'])
val_pred2=xgbmodel.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred2)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred2))
# Out:
# Dev Accuracy: 68.5
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67       100
#            1       0.67      0.73      0.70       100
#
#     accuracy                           0.69       200
#    macro avg       0.69      0.69      0.68       200
# weighted avg       0.69      0.69      0.68       200

# %%
test_predxgb=xgbmodel.predict(test_features1)

# %%
test_predxgbl=label_encoder.inverse_transform(test_predxgb)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test5 = pd.DataFrame(data=test_predxgbl, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test5
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_xgb_68.csv', index = None)

# %%
from sklearn.ensemble import AdaBoostClassifier
adabstmodel = AdaBoostClassifier(n_estimators=50, random_state=42)
adabstmodel.fit(train_features1, df_train['category'])
val_pred2=adabstmodel.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred2)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred2))
# Out:
# Dev Accuracy: 61.5
#
#                precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62       100
#            1       0.62      0.60      0.61       100
#
#     accuracy                           0.61       200
#    macro avg       0.62      0.61      0.61       200
# weighted avg       0.62      0.61      0.61       200

# %%
test_predadabst=adabstmodel.predict(test_features1)

# %%
test_predadaboost=label_encoder.inverse_transform(test_predadabst)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test6 = pd.DataFrame(data=test_predadaboost, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test6
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_adabst_61.csv', index = None)

# %%
from sklearn.svm import SVC
svmmodel = SVC(kernel='rbf', random_state=42)
svmmodel.fit(train_features1, df_train['category'])
val_pred3=svmmodel.predict(val_features1)
accuracy = accuracy_score(df_val['category'], val_pred3)

print("Dev Accuracy:", round(accuracy*100, 4))

print("\n", classification_report(df_val['category'], val_pred3))
# Out:
# Dev Accuracy: 72.0
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.57      0.67       100
#            1       0.67      0.87      0.76       100
#
#     accuracy                           0.72       200
#    macro avg       0.74      0.72      0.71       200
# weighted avg       0.74      0.72      0.71       200

# %%
test_predsvm=svmmodel.predict(test_features1)

# %%
test_predsvm1=label_encoder.inverse_transform(test_predsvm)

# %%
#Submission
# to create .csv file consisting of tweet ids and predicted labels with CTbert
pred_test7 = pd.DataFrame(data=test_predsvm1, columns=['Prediction'])
submission_t1= pd.DataFrame()
submission_t1['id'] = df_test['id']
submission_t1['category'] = pred_test7
submission_t1.to_csv('/content/drive/MyDrive/HOPE2024/Task1_Code/task1_svm_71.csv', index = None)
